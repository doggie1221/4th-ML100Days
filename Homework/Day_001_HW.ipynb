# %%
# 作業1
import numpy as np
import matplotlib.pyplot as plt

# %%
w= 3
b= 0.5
x_lin = np.linspace(0,100,101)

# %%
y = (x_lin + np.random.randn(101) * 5) * w + b

# %%
plt.scatter(x_lin, y, color = 'b', label ='data point', marker =".")
plt.title("Assume we have data points")
plt.legend(loc= 2)
plt.show()

# %%
y_hat = x_lin* w+ b
plt.scatter(x_lin, y, color= "b", marker = ".", label="data")
plt.plot(x_lin, y_hat, color ="r", label= "prediction")
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc=2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE= sum(abs(y-yp))/len(y)
    return(mae)
def mean_square_error(y, yp):
    mse = MSE = sum((y-yp)**2)/len(y)
    return(mse)

# %%
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 11.546
# The Mean square error is 207.510

# %%
# 作業2
# 選擇 Titanic: Machine Learning from Disaster資料集
# 1. 這組資料能給予初學者快速練習數值分析各種面向的資料，且歷史悠久有較多的討論及程式碼可供練手
# 2. 由kaggle平台提供，非企業提供
# 3. 有10個特徵值，為文字及數字資料組成，資料型態有連續型及類別型變數組成
# 4. 預測結果為二分類問題，以confusion matrix之正確率作為評估

# %%
# 作業3
# 1. 分析歷史每月載客量，找尋影響載客量之關鍵特徵值，並可做改善或維持進而提升業績
# 2. 搜集乘客乘客地點、司機資訊、乘客資訊、成交價格、顧客滿意度，部分由公司資料庫取得，部分由設計問卷回饋所得
# 3. 乘客地點、司機資訊、乘客資訊及顧客滿意度為類別型變數，價格為連續型變數
# 4. 根據搜集資訊根據載客量建立預測模型，預測下個月載客量驗證模型正確性，可以MSE作為模型評估標準
